# %%
cd ..
# Out:
# /Users/ianczekala/Documents/TWA-3-orbit

# %%
import src.data as d
import corner
import numpy as np

# %%
d.disk_samples
# Out:
# array([[0.54000457, 0.85787855, 3.60419736],
#        [0.54000457, 0.85787855, 3.60419736],
#        [0.54000457, 0.85787855, 3.60419736],
#        ...,
#        [0.51849468, 0.86957584, 3.61330136],
#        [0.51849468, 0.86957584, 3.61330136],
#        [0.51849468, 0.86957584, 3.61330136]])

# %%
d.disk_samples[:,[1,2]] /= (np.pi/180)

# %%
corner.corner(d.disk_samples, labels=["MA", "incl", "Omega"])
